# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('thor_bombings_clean.csv')

# %%
df['masndate'].str[:7]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\william.monahan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'masndate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\william.monahan\OneDrive - West Point\SE370\Lesson_16_Data\lesson_16_exercise.py:1
# ----> 1 df['masndate'].str[:7]
#
# File c:\Users\william.monahan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\william.monahan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'masndate'

# %%
df['msndate'].str[:7]
# Out:
# 0        1970-11
# 1        1971-09
# 2        1971-04
# 3        1972-08
# 4        1972-09
#           ...
# 35747    1970-05
# 35748    1971-04
# 35749    1972-06
# 35750    1971-10
# 35751    1970-11
# Name: msndate, Length: 35752, dtype: object

# %%
df['year_month'] = df['mndate'].str[:7]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\william.monahan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mndate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\william.monahan\OneDrive - West Point\SE370\Lesson_16_Data\lesson_16_exercise.py:1
# ----> 1 df['year_month'] = df['mndate'].str[:7]
#
# File c:\Users\william.monahan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\william.monahan\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'mndate'

# %%
df['year_month'] = df['msndate'].str[:7]

# %%
df.groupby('year_month').size()
# Out:
# year_month
# 1970-01     664
# 1970-02     566
# 1970-03     506
# 1970-04     585
# 1970-05     810
# 1970-06     633
# 1970-07     458
# 1970-08     387
# 1970-09     358
# 1970-10     327
# 1970-11     387
# 1970-12     705
# 1971-01     872
# 1971-02     756
# 1971-03     809
# 1971-04     981
# 1971-05     944
# 1971-06     600
# 1971-07    1297
# 1971-08    1110
# 1971-09     560
# 1971-10     733
# 1971-11     774
# 1971-12    1058
# 1972-01    1095
# 1972-02     936
# 1972-03     958
# 1972-04    1179
# 1972-05    1740
# 1972-06    1552
# 1972-07    1398
# 1972-08    1482
# 1972-09    1303
# 1972-10    1419
# 1972-11    1215
# 1972-12    1121
# 1973-01    1436
# 1973-02     347
# 1973-03     360
# 1973-04     350
# 1973-05     386
# 1973-06     232
# 1973-07     232
# 1973-08     127
# 1975-05       4
# dtype: int64

# %%
df_plot = df.groupby('year_month').size().reset_index(name = 'count')

# %%
df_plot
# Out:
#    year_month  count
# 0     1970-01    664
# 1     1970-02    566
# 2     1970-03    506
# 3     1970-04    585
# 4     1970-05    810
# 5     1970-06    633
# 6     1970-07    458
# 7     1970-08    387
# 8     1970-09    358
# 9     1970-10    327
# 10    1970-11    387
# 11    1970-12    705
# 12    1971-01    872
# 13    1971-02    756
# 14    1971-03    809
# 15    1971-04    981
# 16    1971-05    944
# 17    1971-06    600
# 18    1971-07   1297
# 19    1971-08   1110
# 20    1971-09    560
# 21    1971-10    733
# 22    1971-11    774
# 23    1971-12   1058
# 24    1972-01   1095
# 25    1972-02    936
# 26    1972-03    958
# 27    1972-04   1179
# 28    1972-05   1740
# 29    1972-06   1552
# 30    1972-07   1398
# 31    1972-08   1482
# 32    1972-09   1303
# 33    1972-10   1419
# 34    1972-11   1215
# 35    1972-12   1121
# 36    1973-01   1436
# 37    1973-02    347
# 38    1973-03    360
# 39    1973-04    350
# 40    1973-05    386
# 41    1973-06    232
# 42    1973-07    232
# 43    1973-08    127
# 44    1975-05      4

# %%
df['year_month'] = df['msndate'].str[:7]

# %%
df_plot = df.groupby('year_month').size().reset_index(name = 'count')

# %%
df_plot
# Out:
#    year_month  count
# 0     1970-01    664
# 1     1970-02    566
# 2     1970-03    506
# 3     1970-04    585
# 4     1970-05    810
# 5     1970-06    633
# 6     1970-07    458
# 7     1970-08    387
# 8     1970-09    358
# 9     1970-10    327
# 10    1970-11    387
# 11    1970-12    705
# 12    1971-01    872
# 13    1971-02    756
# 14    1971-03    809
# 15    1971-04    981
# 16    1971-05    944
# 17    1971-06    600
# 18    1971-07   1297
# 19    1971-08   1110
# 20    1971-09    560
# 21    1971-10    733
# 22    1971-11    774
# 23    1971-12   1058
# 24    1972-01   1095
# 25    1972-02    936
# 26    1972-03    958
# 27    1972-04   1179
# 28    1972-05   1740
# 29    1972-06   1552
# 30    1972-07   1398
# 31    1972-08   1482
# 32    1972-09   1303
# 33    1972-10   1419
# 34    1972-11   1215
# 35    1972-12   1121
# 36    1973-01   1436
# 37    1973-02    347
# 38    1973-03    360
# 39    1973-04    350
# 40    1973-05    386
# 41    1973-06    232
# 42    1973-07    232
# 43    1973-08    127
# 44    1975-05      4

# %%
ax.bar(df_plot['year_month'], df_plot['count'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File c:\Users\william.monahan\OneDrive - West Point\SE370\Lesson_16_Data\lesson_16_exercise.py:1
# ----> 1 ax.bar(df_plot['year_month'], df_plot['count'])
#
# NameError: name 'ax' is not defined

# %%
fig, ax = plt.subplots()
ax.bar(df_plot['year_month'], df_plot['count'])
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(df_plot['year_month'], df_plot['count'])
ax.set_xticklabels(df_plot['year_month'], rotation = 30, ha = 'right')
plt.show()
# Out:
# <ipython-input-19-30fcef8d6252>:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_plot['year_month'], rotation = 30, ha = 'right')

# %%
fig, ax = plt.subplots()
ax.bar(df_plot['year_month'], df_plot['count'])
ax.set_xticklabels(df_plot['year_month'], rotation = 90, ha = 'right')
plt.show()
# Out:
# <ipython-input-20-4c031e9929bb>:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_plot['year_month'], rotation = 90, ha = 'right')

# %%
fig, ax = plt.subplots()
ax.bar(df_plot['year_month'], df_plot['count'])
ax.set_xticklabels(df_plot['year_month'], rotation = 90, ha = 'left')
plt.show()
# Out:
# <ipython-input-21-0a6ce111538c>:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(df_plot['year_month'], rotation = 90, ha = 'left')

# %%
fig, ax = plt.subplots()
ax.bar(df_plot['year_month'], df_plot['count'])
ax.set_xticks(df_plot['year_month'][::3])
ax.set_xticklabels(df_plot['year_month'], rotation = 60, ha = 'right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\william.monahan\OneDrive - West Point\SE370\Lesson_16_Data\lesson_16_exercise.py:4
#       2 ax.bar(df_plot['year_month'], df_plot['count'])
#       3 ax.set_xticks(df_plot['year_month'][::3])
# ----> 4 ax.set_xticklabels(df_plot['year_month'], rotation = 60, ha = 'right')
#       5 plt.show()
#
# File c:\Users\william.monahan\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File c:\Users\william.monahan\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axis.py:2106, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2102 elif isinstance(locator, mticker.FixedLocator):
#    2103     # Passing [] as a list of labels is often used as a way to
#    2104     # remove all tick labels, so only error for > 0 labels
#    2105     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2106         raise ValueError(
#    2107             "The number of FixedLocator locations"
#    2108             f" ({len(locator.locs)}), usually from a call to"
#    2109             " set_ticks, does not match"
#    2110             f" the number of labels ({len(labels)}).")
#    2111     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2112     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (15), usually from a call to set_ticks, does not match the number of labels (45).

# %%
fig, ax = plt.subplots()
ax.bar(df_plot['year_month'], df_plot['count'])
ax.set_xticks(df_plot['year_month'][::3])
ax.set_xticklabels(df_plot['year_month'][::3], rotation = 60, ha = 'right')
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(df_plot['year_month'], df_plot['count'])
ax.set_xticks(df_plot['year_month'][::3])
ax.set_xticklabels(df_plot['year_month'][::3], rotation = 60, ha = 'right')
ax.set_xlabel('Year and Month')
ax.set_ylabel('Number of Bombings')
ax.set_title('Crushing it in Vietnam')
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(df_plot['year_month'], df_plot['count'],color = "red")
ax.set_xticks(df_plot['year_month'][::3])
ax.set_xticklabels(df_plot['year_month'][::3], rotation = 60, ha = 'right')
ax.set_xlabel('Year and Month')
ax.set_ylabel('Number of Bombings')
ax.set_title('Crushing it in Vietnam')
plt.show()

# %%
fig, ax = plt.subplots(dpi = 300)
ax.bar(df_plot['year_month'], df_plot['count'],color = "red")
ax.set_xticks(df_plot['year_month'][::3])
ax.set_xticklabels(df_plot['year_month'][::3], rotation = 60, ha = 'right')
ax.set_xlabel('Year and Month')
ax.set_ylabel('Number of Bombings')
ax.set_title('Crushing it in Vietnam')
plt.show()

# %%
fig, ax = plt.subplots(dpi = 300)
ax.bar(df_plot['year_month'], df_plot['count'],color = "red")
ax.set_xticks(df_plot['year_month'][::3])
ax.set_xticklabels(df_plot['year_month'][::3], rotation = 60, ha = 'right')
ax.set_xlabel('Year and Month')
ax.set_ylabel('Number of Bombings')
ax.set_title('Crushing it in Vietnam')
plt.savefig('g1_barplot.png')
plt.show()
